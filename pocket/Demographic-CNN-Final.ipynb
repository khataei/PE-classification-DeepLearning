# %% [markdown]
# # Activity Classifier

# %% [markdown]
# In this notebook, we build a CNN neural net to classify PE activity. We use demographic data as well as the ecceleration data

# %% [markdown]
# #### Load dependencies

# %%
import tensorflow
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Flatten, Dropout, Conv1D, Concatenate , Input
from tensorflow.keras.layers import GlobalAveragePooling1D, GlobalMaxPooling1D, MaxPool1D,AveragePooling1D
from tensorflow.keras.callbacks import ModelCheckpoint 
from sklearn.metrics import confusion_matrix
from sklearn.metrics import  accuracy_score as score

import os 
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer, StandardScaler
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 


# Visiualization imports, Netron and tensorboard:
import netron
import seaborn as sns
from datetime import datetime
from packaging import version
from tensorflow import keras

# %%
# Try to get reproducable results
from numpy.random import seed
seed(85)
from tensorflow.random import set_seed
set_seed(75)

# %% [markdown]
# #### Set hyperparameters

# %%
# output directory name:
output_dir = 'model_output/demographic-cnn'
input_dir =  'Z:/Research/dfuller/Walkabilly/studies/smarphone_accel/data/Ethica_Jaeger_Merged/pocket/'
input_file_name = 'pocket-NN-data.npz'

# from the data preparation section we have:
window_size_second = 3
frequency = 30
lenght_of_each_seq = window_size_second * frequency



n_dense_2= 512
n_dense_1= 512
n_conv_3= 256
n_conv_2= 512
n_conv_1= 512
maxpooling_pool_size= 2
k_conv_3= 2
k_conv_2= 2
k_conv_1= 2
dropout_2= 0.2
dropout_1= 0.2
avepooling_pool_size= 2
activation_dense = 'relu'
activation_conv = 'relu'


# training:
epochs = 120
batch_size = 256

# %% [markdown]
# #### Load data

# %% [markdown]
# ##### For this notebook we use the acceleration data gathered from the pocket location. It was prepared in the DataPrep-Deep notebook

# %%
# read the raw file and get the keys:
raw_data = np.load(file=input_dir+input_file_name,allow_pickle=True)
for k in raw_data.keys():
    print(k)
# Out:
# acceleration_data
# metadata
# labels

# %%
raw_data['metadata'][2]
# Out:
# array([164.,  68.,  30.,   0.])

# %%
# import the data

accel_array = raw_data['acceleration_data']
meta_array = raw_data['metadata']
labels_array = raw_data['labels']
accel_input_shape = list(accel_array.shape)
meta_input_shape = list(meta_array.shape)

# %% [markdown]
# #### Preprocess data

# %% [markdown]
# ### Data preparation
# 1- Convert the  labels to integer.
# In the raw data format of the labels is String and there are 6 classes. 'Lying', 'Sitting', 'Self Pace walk', 'Running 3 METs',
#        'Running 5 METs', 'Running 7 METs' <br>
#
# 2- Standardize the demographic data
# 3- Split and shuffle

# %%
lb = LabelBinarizer()
y = lb.fit_transform(labels_array)
n_class = len(lb.classes_)
class_list = lb.classes_

# %%
sc = StandardScaler()
meta_array = sc.fit_transform(meta_array)

# %%
X_train_index, X_valid_index, y_train, y_valid = train_test_split(
     (np.arange(len(accel_array))), y, test_size=0.1, random_state=65)
X_accel_train = accel_array[X_train_index]
X_accel_valid = accel_array[X_valid_index]
X_meta_train = meta_array[X_train_index]
X_meta_valid = meta_array[X_valid_index]

# %% [markdown]
# #### Design neural network architecture using functional API

# %%
accel_input = Input(shape=accel_input_shape[1:], name="Acceleration-data")
meta_input = Input(shape=meta_input_shape[1:], name="Demographic-data")
x = Conv1D(n_conv_1, k_conv_1, activation=activation_conv)(accel_input)
x = MaxPool1D(pool_size = maxpooling_pool_size)(x)
x = Conv1D(n_conv_2, k_conv_2, activation=activation_conv)(x)
x = AveragePooling1D(pool_size = avepooling_pool_size)(x)
x = Conv1D(n_conv_2, k_conv_2, activation=activation_conv)(x)
x = GlobalAveragePooling1D()(x)
meta_input_x = Flatten()(meta_input)
x = Concatenate()([x,meta_input_x])

x = Dense(n_dense_1, activation=activation_dense)(x)
x = Dropout(dropout_1)(x)
x = Dense(n_dense_2, activation=activation_dense)(x)
x = Dropout(dropout_2)(x)



output = Dense(n_class, activation='softmax')(x)
     
model = Model(inputs=[accel_input, meta_input], outputs=output, name='biInput')
model.summary()
# Out:
# Model: "biInput"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Acceleration-data (InputLayer)  [(None, 90, 3)]      0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 89, 512)      3584        Acceleration-data[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 44, 512)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 43, 512)      524800      max_pooling1d[0][0]
# __________________________________________________________________________________________________
# average_pooling1d (AveragePooli (None, 21, 512)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 20, 512)      524800      average_pooling1d[0][0]
# __________________________________________________________________________________________________
# Demographic-data (InputLayer)   [(None, 4)]          0
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 512)          0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 4)            0           Demographic-data[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 516)          0           global_average_pooling1d[0][0]
#                                                                  flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          264704      concatenate[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          262656      dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 6)            3078        dropout_1[0][0]
# ==================================================================================================
# Total params: 1,583,622
# Trainable params: 1,583,622
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Configure model

# %%
model.compile(loss='categorical_crossentropy', optimizer='nadam', metrics=['accuracy'])

# %%
modelcheckpoint = ModelCheckpoint(filepath=output_dir+
                                  "/weights.{epoch:02d}.hdf5")
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %% [markdown]
# #### Train!

# %%
model.fit(x=[X_accel_train, X_meta_train], y=y_train, 
         batch_size=batch_size, epochs=epochs, verbose=1, 
         validation_data=([X_accel_valid, X_meta_valid], y_valid), 
          callbacks=[modelcheckpoint])
# Out:
# Epoch 1/120
#   1/228 [..............................] - ETA: 0s - loss: 1.7988 - accuracy: 0.1445WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0180s vs `on_train_batch_end` time: 0.0279s). Check your callbacks.
# 228/228 [==============================] - 11s 50ms/step - loss: 0.9853 - accuracy: 0.5945 - val_loss: 0.8261 - val_accuracy: 0.6472
# Epoch 2/120
# 228/228 [==============================] - 11s 47ms/step - loss: 0.5245 - accuracy: 0.8023 - val_loss: 0.3677 - val_accuracy: 0.8661
# Epoch 3/120
# 228/228 [==============================] - 11s 47ms/step - loss: 0.3558 - accuracy: 0.8728 - val_loss: 0.2648 - val_accuracy: 0.9126
# Epoch 4/120
# 228/228 [==============================] - 11s 47ms/step - loss: 0.2614 - accuracy: 0.9140 - val_loss: 0.1913 - val_accuracy: 0.9387
# Epoch 5/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.2065 - accuracy: 0.9335 - val_loss: 0.1728 - val_accuracy: 0.9432
# Epoch 6/120
# 228/228 [==============================] - 11s 47ms/step - loss: 0.1789 - accuracy: 0.9418 - val_loss: 0.1560 - val_accuracy: 0.9477
# Epoch 7/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.1722 - accuracy: 0.9451 - val_loss: 0.1424 - val_accuracy: 0.9520
# Epoch 8/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.1438 - accuracy: 0.9530 - val_loss: 0.1572 - val_accuracy: 0.9472
# Epoch 9/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.1521 - accuracy: 0.9515 - val_loss: 0.1371 - val_accuracy: 0.9558
# Epoch 10/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.1286 - accuracy: 0.9586 - val_loss: 0.1446 - val_accuracy: 0.9506
# Epoch 11/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.1178 - accuracy: 0.9609 - val_loss: 0.1165 - val_accuracy: 0.9646
# Epoch 12/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.1206 - accuracy: 0.9604 - val_loss: 0.1326 - val_accuracy: 0.9498
# Epoch 13/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.1104 - accuracy: 0.9641 - val_loss: 0.1158 - val_accuracy: 0.9634
# Epoch 14/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0993 - accuracy: 0.9668 - val_loss: 0.1130 - val_accuracy: 0.9636
# Epoch 15/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0959 - accuracy: 0.9688 - val_loss: 0.1127 - val_accuracy: 0.9611
# Epoch 16/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0933 - accuracy: 0.9682 - val_loss: 0.1142 - val_accuracy: 0.9626
# Epoch 17/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0872 - accuracy: 0.9706 - val_loss: 0.1107 - val_accuracy: 0.9660
# Epoch 18/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0861 - accuracy: 0.9706 - val_loss: 0.1079 - val_accuracy: 0.9654
# Epoch 19/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0765 - accuracy: 0.9745 - val_loss: 0.1163 - val_accuracy: 0.9612
# Epoch 20/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0789 - accuracy: 0.9730 - val_loss: 0.1188 - val_accuracy: 0.9606
# Epoch 21/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0770 - accuracy: 0.9736 - val_loss: 0.1095 - val_accuracy: 0.9649
# Epoch 22/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0704 - accuracy: 0.9758 - val_loss: 0.1104 - val_accuracy: 0.9651
# Epoch 23/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0687 - accuracy: 0.9767 - val_loss: 0.1041 - val_accuracy: 0.9653
# Epoch 24/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0700 - accuracy: 0.9757 - val_loss: 0.1060 - val_accuracy: 0.9676
# Epoch 25/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0642 - accuracy: 0.9777 - val_loss: 0.0996 - val_accuracy: 0.9716
# Epoch 26/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0623 - accuracy: 0.9788 - val_loss: 0.1071 - val_accuracy: 0.9705
# Epoch 27/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0607 - accuracy: 0.9782 - val_loss: 0.1075 - val_accuracy: 0.9687
# Epoch 28/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0607 - accuracy: 0.9788 - val_loss: 0.1037 - val_accuracy: 0.9700
# Epoch 29/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0577 - accuracy: 0.9792 - val_loss: 0.1046 - val_accuracy: 0.9704
# Epoch 30/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0547 - accuracy: 0.9807 - val_loss: 0.1098 - val_accuracy: 0.9691
# Epoch 31/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0522 - accuracy: 0.9819 - val_loss: 0.1025 - val_accuracy: 0.9713
# Epoch 32/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0528 - accuracy: 0.9814 - val_loss: 0.1036 - val_accuracy: 0.9704
# Epoch 33/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0490 - accuracy: 0.9828 - val_loss: 0.1025 - val_accuracy: 0.9685
# Epoch 34/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0535 - accuracy: 0.9819 - val_loss: 0.1029 - val_accuracy: 0.9702
# Epoch 35/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0488 - accuracy: 0.9825 - val_loss: 0.1080 - val_accuracy: 0.9671
# Epoch 36/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0487 - accuracy: 0.9823 - val_loss: 0.1224 - val_accuracy: 0.9663
# Epoch 37/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0475 - accuracy: 0.9831 - val_loss: 0.1211 - val_accuracy: 0.9688
# Epoch 38/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0430 - accuracy: 0.9843 - val_loss: 0.1122 - val_accuracy: 0.9679
# Epoch 39/120
# 228/228 [==============================] - 11s 49ms/step - loss: 0.0425 - accuracy: 0.9846 - val_loss: 0.1063 - val_accuracy: 0.9710
# Epoch 40/120
# 228/228 [==============================] - 11s 49ms/step - loss: 0.0424 - accuracy: 0.9852 - val_loss: 0.1147 - val_accuracy: 0.9705
# Epoch 41/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0474 - accuracy: 0.9837 - val_loss: 0.1189 - val_accuracy: 0.9679
# Epoch 42/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0399 - accuracy: 0.9859 - val_loss: 0.1368 - val_accuracy: 0.9636
# Epoch 43/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0401 - accuracy: 0.9858 - val_loss: 0.1224 - val_accuracy: 0.9693
# Epoch 44/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0424 - accuracy: 0.9850 - val_loss: 0.1022 - val_accuracy: 0.9731
# Epoch 45/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0390 - accuracy: 0.9859 - val_loss: 0.1047 - val_accuracy: 0.9730
# Epoch 46/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0425 - accuracy: 0.9854 - val_loss: 0.1090 - val_accuracy: 0.9708
# Epoch 47/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0364 - accuracy: 0.9868 - val_loss: 0.1074 - val_accuracy: 0.9733
# Epoch 48/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0396 - accuracy: 0.9865 - val_loss: 0.1126 - val_accuracy: 0.9708
# Epoch 49/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0360 - accuracy: 0.9872 - val_loss: 0.1157 - val_accuracy: 0.9714
# Epoch 50/120
# 228/228 [==============================] - 11s 49ms/step - loss: 0.0357 - accuracy: 0.9872 - val_loss: 0.1114 - val_accuracy: 0.9717
# Epoch 51/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0333 - accuracy: 0.9886 - val_loss: 0.0994 - val_accuracy: 0.9748
# Epoch 52/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0342 - accuracy: 0.9882 - val_loss: 0.1348 - val_accuracy: 0.9713
# Epoch 53/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0371 - accuracy: 0.9868 - val_loss: 0.1114 - val_accuracy: 0.9730
# Epoch 54/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0315 - accuracy: 0.9887 - val_loss: 0.1125 - val_accuracy: 0.9710
# Epoch 55/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0363 - accuracy: 0.9872 - val_loss: 0.1167 - val_accuracy: 0.9683
# Epoch 56/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0329 - accuracy: 0.9888 - val_loss: 0.1202 - val_accuracy: 0.9697
# Epoch 57/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0315 - accuracy: 0.9888 - val_loss: 0.1235 - val_accuracy: 0.9708
# Epoch 58/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0372 - accuracy: 0.9874 - val_loss: 0.1142 - val_accuracy: 0.9736
# Epoch 59/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0308 - accuracy: 0.9889 - val_loss: 0.1156 - val_accuracy: 0.9724
# Epoch 60/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0284 - accuracy: 0.9899 - val_loss: 0.1143 - val_accuracy: 0.9728
# Epoch 61/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0315 - accuracy: 0.9894 - val_loss: 0.1180 - val_accuracy: 0.9727
# Epoch 62/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0338 - accuracy: 0.9885 - val_loss: 0.1112 - val_accuracy: 0.9731
# Epoch 63/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0318 - accuracy: 0.9896 - val_loss: 0.1117 - val_accuracy: 0.9753
# Epoch 64/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0293 - accuracy: 0.9894 - val_loss: 0.1160 - val_accuracy: 0.9734
# Epoch 65/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0328 - accuracy: 0.9889 - val_loss: 0.1336 - val_accuracy: 0.9734
# Epoch 66/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0289 - accuracy: 0.9898 - val_loss: 0.1358 - val_accuracy: 0.9714
# Epoch 67/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0289 - accuracy: 0.9902 - val_loss: 0.1182 - val_accuracy: 0.9733
# Epoch 68/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0269 - accuracy: 0.9908 - val_loss: 0.1230 - val_accuracy: 0.9705
# Epoch 69/120
# 228/228 [==============================] - 11s 47ms/step - loss: 0.0328 - accuracy: 0.9889 - val_loss: 0.1442 - val_accuracy: 0.9687
# Epoch 70/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0290 - accuracy: 0.9903 - val_loss: 0.1172 - val_accuracy: 0.9751
# Epoch 71/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0245 - accuracy: 0.9913 - val_loss: 0.1345 - val_accuracy: 0.9708
# Epoch 72/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0261 - accuracy: 0.9910 - val_loss: 0.1267 - val_accuracy: 0.9707
# Epoch 73/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0294 - accuracy: 0.9897 - val_loss: 0.1135 - val_accuracy: 0.9767
# Epoch 74/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0302 - accuracy: 0.9896 - val_loss: 0.1130 - val_accuracy: 0.9744
# Epoch 75/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0265 - accuracy: 0.9909 - val_loss: 0.1188 - val_accuracy: 0.9736
# Epoch 76/120
# 228/228 [==============================] - 11s 47ms/step - loss: 0.0238 - accuracy: 0.9913 - val_loss: 0.1153 - val_accuracy: 0.9756
# Epoch 77/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0324 - accuracy: 0.9889 - val_loss: 0.1226 - val_accuracy: 0.9756
# Epoch 78/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0261 - accuracy: 0.9909 - val_loss: 0.1405 - val_accuracy: 0.9705
# Epoch 79/120
# 228/228 [==============================] - 11s 47ms/step - loss: 0.0254 - accuracy: 0.9910 - val_loss: 0.1332 - val_accuracy: 0.9711
# Epoch 80/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0256 - accuracy: 0.9908 - val_loss: 0.1270 - val_accuracy: 0.9736
# Epoch 81/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0244 - accuracy: 0.9909 - val_loss: 0.1194 - val_accuracy: 0.9762
# Epoch 82/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0265 - accuracy: 0.9908 - val_loss: 0.1261 - val_accuracy: 0.9730
# Epoch 83/120
# 228/228 [==============================] - 11s 47ms/step - loss: 0.0252 - accuracy: 0.9916 - val_loss: 0.1299 - val_accuracy: 0.9737
# Epoch 84/120
# 228/228 [==============================] - 11s 47ms/step - loss: 0.0236 - accuracy: 0.9913 - val_loss: 0.1302 - val_accuracy: 0.9753
# Epoch 85/120
# 228/228 [==============================] - 11s 47ms/step - loss: 0.0227 - accuracy: 0.9924 - val_loss: 0.1452 - val_accuracy: 0.9702
# Epoch 86/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0282 - accuracy: 0.9903 - val_loss: 0.1324 - val_accuracy: 0.9742
# Epoch 87/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0257 - accuracy: 0.9909 - val_loss: 0.1233 - val_accuracy: 0.9758
# Epoch 88/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0245 - accuracy: 0.9917 - val_loss: 0.1518 - val_accuracy: 0.9705
# Epoch 89/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0244 - accuracy: 0.9916 - val_loss: 0.1328 - val_accuracy: 0.9727
# Epoch 90/120
# 228/228 [==============================] - 11s 47ms/step - loss: 0.0238 - accuracy: 0.9920 - val_loss: 0.1362 - val_accuracy: 0.9750
# Epoch 91/120
# 228/228 [==============================] - 11s 47ms/step - loss: 0.0210 - accuracy: 0.9926 - val_loss: 0.1253 - val_accuracy: 0.9770
# Epoch 92/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0230 - accuracy: 0.9921 - val_loss: 0.1164 - val_accuracy: 0.9748
# Epoch 93/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0220 - accuracy: 0.9922 - val_loss: 0.1312 - val_accuracy: 0.9747
# Epoch 94/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0238 - accuracy: 0.9924 - val_loss: 0.1257 - val_accuracy: 0.9764
# Epoch 95/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0235 - accuracy: 0.9920 - val_loss: 0.1293 - val_accuracy: 0.9744
# Epoch 96/120
# 228/228 [==============================] - 11s 47ms/step - loss: 0.0224 - accuracy: 0.9929 - val_loss: 0.1268 - val_accuracy: 0.9747
# Epoch 97/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0205 - accuracy: 0.9929 - val_loss: 0.1613 - val_accuracy: 0.9727
# Epoch 98/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0242 - accuracy: 0.9915 - val_loss: 0.1374 - val_accuracy: 0.9744
# Epoch 99/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0250 - accuracy: 0.9915 - val_loss: 0.1238 - val_accuracy: 0.9762
# Epoch 100/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0197 - accuracy: 0.9933 - val_loss: 0.1239 - val_accuracy: 0.9744
# Epoch 101/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0190 - accuracy: 0.9935 - val_loss: 0.1283 - val_accuracy: 0.9750
# Epoch 102/120
# 228/228 [==============================] - 11s 47ms/step - loss: 0.0244 - accuracy: 0.9918 - val_loss: 0.1514 - val_accuracy: 0.9690
# Epoch 103/120
# 228/228 [==============================] - 11s 47ms/step - loss: 0.0254 - accuracy: 0.9915 - val_loss: 0.1346 - val_accuracy: 0.9731
# Epoch 104/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0187 - accuracy: 0.9935 - val_loss: 0.1440 - val_accuracy: 0.9767
# Epoch 105/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0188 - accuracy: 0.9934 - val_loss: 0.1462 - val_accuracy: 0.9741
# Epoch 106/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0258 - accuracy: 0.9917 - val_loss: 0.1295 - val_accuracy: 0.9710
# Epoch 107/120
# 228/228 [==============================] - 11s 47ms/step - loss: 0.0209 - accuracy: 0.9924 - val_loss: 0.1333 - val_accuracy: 0.9730
# Epoch 108/120
# 228/228 [==============================] - 11s 47ms/step - loss: 0.0228 - accuracy: 0.9921 - val_loss: 0.1245 - val_accuracy: 0.9756
# Epoch 109/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0184 - accuracy: 0.9937 - val_loss: 0.1288 - val_accuracy: 0.9754
# Epoch 110/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0190 - accuracy: 0.9935 - val_loss: 0.1260 - val_accuracy: 0.9764
# Epoch 111/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0197 - accuracy: 0.9935 - val_loss: 0.1340 - val_accuracy: 0.9736
# Epoch 112/120
# 228/228 [==============================] - 11s 47ms/step - loss: 0.0224 - accuracy: 0.9924 - val_loss: 0.1232 - val_accuracy: 0.9747
# Epoch 113/120
# 228/228 [==============================] - 11s 47ms/step - loss: 0.0197 - accuracy: 0.9936 - val_loss: 0.1414 - val_accuracy: 0.9727
# Epoch 114/120
# 228/228 [==============================] - 11s 47ms/step - loss: 0.0224 - accuracy: 0.9923 - val_loss: 0.1408 - val_accuracy: 0.9759
# Epoch 115/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0219 - accuracy: 0.9925 - val_loss: 0.1256 - val_accuracy: 0.9756
# Epoch 116/120
# 228/228 [==============================] - 11s 47ms/step - loss: 0.0171 - accuracy: 0.9941 - val_loss: 0.1347 - val_accuracy: 0.9754
# Epoch 117/120
# 228/228 [==============================] - 11s 47ms/step - loss: 0.0178 - accuracy: 0.9935 - val_loss: 0.1271 - val_accuracy: 0.9739
# Epoch 118/120
# 228/228 [==============================] - 11s 47ms/step - loss: 0.0189 - accuracy: 0.9935 - val_loss: 0.1340 - val_accuracy: 0.9761
# Epoch 119/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0232 - accuracy: 0.9924 - val_loss: 0.1502 - val_accuracy: 0.9739
# Epoch 120/120
# 228/228 [==============================] - 11s 48ms/step - loss: 0.0187 - accuracy: 0.9934 - val_loss: 0.1522 - val_accuracy: 0.9731

# %% [markdown]
# #### Evaluate

# %%
model.load_weights(output_dir+"/weights.91.hdf5") # 97.70

# %%
y_hat = model.predict([X_accel_valid, X_meta_valid])

# %%
plt.hist(y_hat)
_ = plt.axvline(x=0.5, color='orange')

# %% [markdown]
# #### Histogram of probabilities for each class
# If most probabilities are around either zero or one, it means the model was confidant in classification

# %%
df = pd.DataFrame(y_hat, columns=class_list)
_ = df.hist(figsize=(15,10), color='brown')

# %%
# Calculate ROC and Accuracy
pct_auc = roc_auc_score(y_valid, y_hat)*100.0
y_pred_classes = y_hat.round()
acc = score(y_valid, y_pred_classes) * 100

# %%
print("The model accuracy is: {:0.2f}".format(acc))
print("The area under ROC curve is: {:0.2f}".format(pct_auc))
# Out:
# The model accuracy is: 97.58
# The area under ROC curve is: 99.87

# %% [markdown]
# #### plot confusion matrix
# First use seaborn, then a custom stript.

# %%
# convert probability to class
y_pred_class = np.argmax(y_hat, axis=1)
y_class = np.argmax(y_valid, axis = 1)

# %%
# Create confucion matrix:
cf_matrix = confusion_matrix(y_class, y_pred_class, labels=range(len(class_list)))


# the classes are not in order, for example 'sitting' is not following 'lying'. Sort them:

confusion_matrix_df = pd.DataFrame(cf_matrix, index=class_list, columns=class_list)
confusion_matrix_df = confusion_matrix_df[['Lying','Sitting', 'Self Pace walk',\
                                           'Running 3 METs','Running 5 METs', 'Running 7 METs']]
confusion_matrix_df = confusion_matrix_df.reindex(['Lying', 'Sitting', 'Self Pace walk',\
                                                   'Running 3 METs','Running 5 METs', 'Running 7 METs'])
_ = sns.heatmap(cf_matrix, annot=True, fmt = '1', xticklabels=class_list, yticklabels=class_list, cmap='ocean')

# %%
plt.figure(figsize = (13,10))

_ = sns.heatmap(confusion_matrix_df, annot=True, fmt = '1', cmap='rocket_r') # try cmap='rocket', 'PuBuGn', 'magma'

# %%
import prettyconfusion as pf
pf.pretty_plot_confusion_matrix(confusion_matrix_df,cmap='PuBuGn', cbar='oranges'
                                ,fz = 13, lw=1, figsize=[12,12])

# %%
# All stored weights have the same structure. Load one of them to netron and save the image 
netron.start(file=output_dir+"/weights.01.hdf5")
# Out:
# Serving 'model_output/demographic-cnn/weights.01.hdf5' at http://localhost:8080
